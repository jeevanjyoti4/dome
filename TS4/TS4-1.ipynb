# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# $\sigma_a^\prime = (\sigma_a^2 + 3 \tau_a^2)^{1/2} = \left[ \left(  \dfrac{32K_f M_a}{\pi d^3} \right)^2 + 3\left( \dfrac{16 K_{fs} T_a}{\pi d^3} \right) \right]^{1/2}$
#
# $\sigma_m^\prime = (\sigma_m^2 + 3 \tau_m^2)^{1/2} = \left[ \left(  \dfrac{32K_f M_m}{\pi d^3} \right)^2 + 3\left( \dfrac{16 K_{fs} T_m}{\pi d^3} \right) \right]^{1/2}$
#
#
# For Goodman:
#
# \begin{align*}
# \dfrac{1}{n} &= \dfrac{\sigma_a^\prime}{S_e} + \dfrac{\sigma_m^\prime}{S_{ut}}\\
# &= \dfrac{16}{\pi d^3} \left\{ \dfrac{1}{S_e}\left[ 4(K_f M_a)^2 + 3(K_{fs}T_a)^2\right]^{1/2} + \dfrac{1}{S_{ut}} \left[ 4(K_f M_m)^2 + 3(K_{fs} T_m)^2 \right]^{1/2} \right\}
# \end{align*}
#
# Solving for the diameter:
# \begin{align*}
# d &= \left( \dfrac{16n}{\pi} \left\{ \dfrac{1}{S_e}\left[ 4(K_f M_a)^2 + 3(K_{fs}T_a)^2\right]^{1/2} + \dfrac{1}{S_{ut}} \left[ 4(K_f M_m)^2 + 3(K_{fs} T_m)^2 \right]^{1/2} \right\} \right)^{1/3} \\
# &= \left( \dfrac{16n}{\pi} \left\{ \dfrac{A}{S_e} + \dfrac{B}{S_{ut}} \right\} \right)^{1/3}
# \end{align*}
#
# where
#
# $A = \left[ 4(K_f M_a)^2 + 3(K_{fs}T_a)^2\right]^{1/2}$
#
# $B = \left[ 4(K_f M_m)^2 + 3(K_{fs} T_m)^2\right]^{1/2}$

# %%
from math import pi

# %%
Ma = 70
Ta = 45
Mm = 55
Tm = 35

Kf = 2.2
Kfs = 1.8

Sut = 700e6
Se = 210e6

A = ( 4*(Kf*Ma)**2 + 3*(Kfs*Ta)**2 )**(1/2)
B = ( 4*(Kf*Mm)**2 + 3*(Kfs*Tm)**2 )**(1/2)

n = 2

d = (16*n/pi*(A/Se + B/Sut))**(1/3)
display(d)
# Out:
# 0.02726983495245188
