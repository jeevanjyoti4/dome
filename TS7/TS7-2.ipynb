# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
m = 6
vel_ratio = 4
Z1 = 16

# %% [markdown]
# \begin{gather*}
# \frac{d_2}{d_1} = \frac{n_1}{n_2} = 4
# \end{gather*}
#
# \begin{gather*}
# m = \frac{d_1}{Z_1} = \frac{d_2}{Z_2} \\
# \implies Z_2 = Z_1 \frac{d_2}{d_1}
# \end{gather*}

# %%
Z2 = 16*4
display(Z2)
# Out:
# 64

# %%
d1 = m*Z1
d2 = m*Z2

O1O2 = (d1 + d2)/2

display(d1, d2, O1O2)
# Out:
# 96
# 384
# 240.0
