# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
Z1 = 15
Z2 = 60

m = 3
n1 = 1600

# %%
d1 = m*Z1
display(d1)
# Out:
# 45

# %%
d2 = m*Z2
display(d2)
# Out:
# 180

# %%
n2 = n1*d1/d2
display(n2)
# Out:
# 400.0

# %%
from math import pi

# %%
p = pi*m
display(p)
# Out:
# 9.42477796076938

# %%
O1O2 = (d1+d2)/2
display(O1O2)
# Out:
# 112.5
