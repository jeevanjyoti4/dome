# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from math import pi

# %%
m = 1.25e-3
Z = 18
n = 1800
H = 0.5e3
F = 12e-3

d = m*Z

V = pi*d*(n/60)

Kv = (6.1 + V)/6.1 # cut teeth

Wt = H/V



Y = 0.309 # for 18 teeth on a 20 degree pressure angle system

sigma = Kv*Wt/(F*m*Y)
display(sigma/1e6) #in MPa
# Out:
# 68.55497604997542
