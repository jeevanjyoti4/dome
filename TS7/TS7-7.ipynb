# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from math import pi

# %%
m = 8e-3
F = 90E-3
Z = 16
n = 150
H = 6000

d = m*Z

V = pi*d*(n/60)

Kv = (6.1 + V)/6.1

Y = 0.296 # for 16 teeth on a 20 degree pressure angle system

Wt = H/V

sigma = Kv*Wt/(F*m*Y)
display(sigma/1e6)
# Out:
# 32.619730308385535
